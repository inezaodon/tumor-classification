# %% [markdown]
# ### From Claude (Can Change):
# Data loading + directory walk (confirm image counts)
# Sample image grid (4 classes × ~5 images)
# Image dimension analysis + class balance plot
# Preprocessing pipeline (resize, normalize)
# Baseline 1: majority-class predictor
# Baseline 2: flatten → logistic regression
# Baseline 3: brightness threshold heuristic
# Metrics table: accuracy, precision, recall, F1, confusion matrix for each baseline
